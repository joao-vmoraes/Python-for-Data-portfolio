# %%
#creating a dataframe with pandas
import pandas as pd

data = pd.DataFrame({
    'João': ['i like it', 'i dont know about it', 'i dont like it'], 
    'Clair': ['the worst thing that i watched', 'i like it', 'i dont like it']},
    index=['movie1', 'movie2', 'movie3'])

display(data)
# Out:
#                         João                           Clair
# movie1             i like it  the worst thing that i watched
# movie2  i dont know about it                       i like it
# movie3        i dont like it                  i dont like it
