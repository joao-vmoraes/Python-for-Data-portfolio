# %%
#creating a dataframe with pandas
import pandas as pd

data = pd.DataFrame({
    'Name': ['joao', 'maria', 'jose'], 
    'Age': [25, 30, 35]
})

display(data)
# Out:
#     Name  Age
# 0   joao   25
# 1  maria   30
# 2   jose   35
